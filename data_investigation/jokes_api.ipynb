# %%
from datasets import load_dataset
import pandas as pd
import re
from sentence_transformers import SentenceTransformer
from tqdm.auto import tqdm
import numpy as np
# Out:
# /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
api_df = pd.read_json("data/jokes_api.json")

# %%
api_df
# Out:
#             type                                              setup  \
# 0        general        What did the fish say when it hit the wall?
# 1        general                    How do you make a tissue dance?
# 2        general                    What's Forrest Gump's password?
# 3        general       What do you call a belt made out of watches?
# 4        general             Why can't bicycles stand on their own?
# ..           ...                                                ...
# 446  programming  Why did the developer break up with their keyb...
# 447  programming      Why did the programmer always carry a pencil?
# 448      general              Why don't skeletons fight each other?
# 449      general                   What do you call fake spaghetti?
# 450      general             What do you call a thieving alligator?
#
#                               punchline
# 0                                  Dam.
# 1        You put a little boogie on it.
# ...

# %%
api_df['setup'].value_counts()
# Out:
# setup
# Why did the cookie cry?                                2
# Why does Waldo only wear stripes?                      2
# Why don't programmers like nature?                     2
# What's the best thing about a Boolean?                 2
# Why did the coffee file a police report?               2
#                                                       ..
# Is the pool safe for diving?                           1
# How was the snow globe feeling after the storm?        1
# How much does a hipster weigh?                         1
# How many tickles does it take to tickle an octopus?    1
# What do you call a thieving alligator?                 1
# Name: count, Length: 445, dtype: int64
