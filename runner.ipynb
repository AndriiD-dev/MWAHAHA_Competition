# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
#%git clone https://github.com/AndriiD-dev/MWAHAHA_Competition.git

# %cd /content/MWAHAHA_Competition

# %pip install -r requirements.txt

# %%
# %run ./training/trainColab.py

# %%
# !zip -r qwen_lora_jokes.zip ./qwen_lora_jokes

# %%
# !mkdir -p /content/drive/MyDrive/mwahaha_models
# !cp /content/qwen_lora_jokes.zip /content/drive/MyDrive/mwahaha_models/

# %%
from google.colab import files
files.download("/content/qwen_lora_jokes.zip")

# %%
# for inference only

from huggingface_hub import login
login()  # token with read access to your private adapter repo

# !python experiments/run_task_a_title.py
# Out:
# /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Project root: /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition
# Data dir    : /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/data
# Output dir  : /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/outputs
# Loading data from: /Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/data/task-a-title.csv
# Total prompts: 1100
# Loading tokenizer from HF repo: An-di/qwen2_5_3b_jokes_lora
# CUDA not available, using CPU (float32)
# Loading base model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards:   0%|                          | 0/2 [00:00<?, ?it/s]^C
# Loading checkpoint shards:   0%|                          | 0/2 [00:04<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/experiments/run_task_a_title.py", line 276, in <module>
#     main()
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/experiments/run_task_a_title.py", line 254, in main
#     model, tokenizer = load_model_and_tokenizer()
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/experiments/run_task_a_title.py", line 87, in load_model_and_tokenizer
#     base_model = AutoModelForCausalLM.from_pretrained(
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/transformers/modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/transformers/modeling_utils.py", line 5048, in from_pretrained
#     ) = cls._load_pretrained_model(
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/transformers/modeling_utils.py", line 5468, in _load_pretrained_model
#     _error_msgs, disk_offload_index = load_shard_file(args)
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/transformers/modeling_utils.py", line 843, in load_shard_file
#     disk_offload_index = _load_state_dict_into_meta_model(
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.9/site-packages/transformers/modeling_utils.py", line 750, in _load_state_dict_into_meta_model
#     param = param.to(casting_dtype)
# KeyboardInterrupt
