# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
#%git clone https://github.com/AndriiD-dev/MWAHAHA_Competition.git

# %cd /content/MWAHAHA_Competition

# %pip install -r requirements.txt

# %%
# %run ./training/trainColab.py

# %%
# !zip -r qwen_lora_jokes.zip ./qwen_lora_jokes

# %%
# !mkdir -p /content/drive/MyDrive/mwahaha_models
# !cp /content/qwen_lora_jokes.zip /content/drive/MyDrive/mwahaha_models/

# %%
from google.colab import files
files.download("/content/qwen_lora_jokes.zip")

# %%
# for inference only

# we will use later for the training
# from huggingface_hub import login
# login()  # token with read access to your private adapter repo



# two words
# !python inference/task_a/two_words/run_task_two_words_clean_qwen.py
# Out:
# Traceback (most recent call last):
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/experiments/run_task_a_title.py", line 12, in <module>
#     from peft import PeftModel
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/peft/__init__.py", line 17, in <module>
#     from .auto import (
#     ...<8 lines>...
#     )
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/peft/auto.py", line 21, in <module>
#     from transformers import (
#     ...<7 lines>...
#     )
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/transformers/__init__.py", line 27, in <module>
#     from . import dependency_versions_check
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/transformers/dependency_versions_check.py", line 57, in <module>
#     require_version_core(deps[pkg])
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/transformers/utils/versions.py", line 117, in require_version_core
#     return require_version(requirement, hint)
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/transformers/utils/versions.py", line 111, in require_version
#     _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/andrey/Documents/_Artemis_tum/Semester5/MWAHAHA_Competition/.venv/lib/python3.13/site-packages/transformers/utils/versions.py", line 44, in _compare_versions
#     raise ImportError(
#         f"{requirement} is required for a normal functioning of this module, but found {pkg}=={got_ver}.{hint}"
#     )
# ImportError: huggingface-hub>=0.34.0,<1.0 is required for a normal functioning of this module, but found huggingface-hub==1.2.3.
# Try: `pip install transformers -U` or `pip install -e '.[dev]'` if you're working with git main

# %%
# headline
# !python inference/task_a/title/run_task_a_title_clean_qwen.py
